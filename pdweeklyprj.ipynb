# %% [markdown]
# TIME SERIES
# 1. APPLE STOCK

# %%
import pandas as pd
import numpy as np
import datetime

# %%
apple = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/09_Time_Series/Apple_Stock/appl_1980_2014.csv')
apple
# Out:
#             Date   Open   High    Low  Close     Volume  Adj Close
# 0     2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 1     2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2     2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 3     2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 4     2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...          ...    ...    ...    ...    ...        ...        ...
# 8460  1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# 8461  1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8462  1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8463  1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8464  1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
#
# [8465 rows x 7 columns]

# %%
#Check out the type of the columns
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8465 non-null   object
#  1   Open       8465 non-null   float64
#  2   High       8465 non-null   float64
#  3   Low        8465 non-null   float64
#  4   Close      8465 non-null   float64
#  5   Volume     8465 non-null   int64
#  6   Adj Close  8465 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 463.1+ KB

# %%
#Transform the Date column as a datetime type
apple['Date']= pd.to_datetime(apple['Date'])
apple.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8465 entries, 0 to 8464
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8465 non-null   datetime64[ns]
#  1   Open       8465 non-null   float64
#  2   High       8465 non-null   float64
#  3   Low        8465 non-null   float64
#  4   Close      8465 non-null   float64
#  5   Volume     8465 non-null   int64
#  6   Adj Close  8465 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 463.1 KB

# %%
#Set the date as the index
apple.set_index('Date',inplace=True)
apple.head(2)
# Out:
#              Open   High    Low  Close    Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97

# %%
# Is there any duplicate dates?
apple.duplicated(keep=False).value_counts()
#no duplicated date
# Out:
# False    8465
# Name: count, dtype: int64

# %%
#Ops...it seems the index is from the most recent date. Make the first entry the oldest date.
apple.sort_index(ascending=False)
# Out:
#            Date   Open   High    Low  Close     Volume  Adj Close
# 8464 1980-12-12  28.75  28.87  28.75  28.75  117258400       0.45
# 8463 1980-12-15  27.38  27.38  27.25  27.25   43971200       0.42
# 8462 1980-12-16  25.37  25.37  25.25  25.25   26432000       0.39
# 8461 1980-12-17  25.87  26.00  25.87  25.87   21610400       0.40
# 8460 1980-12-18  26.63  26.75  26.63  26.63   18362400       0.41
# ...         ...    ...    ...    ...    ...        ...        ...
# 4    2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# 3    2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2    2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 1    2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 0    2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
#
# [8465 rows x 7 columns]

# %%
#Get the last business day of each month

# %%
# What is the difference in days between the first day and the oldest
apple['Date'].max()- apple['Date'].min()
# Out:
# Timedelta('12261 days 00:00:00')

# %%
#How many months in the data we have

# %%
#Plot the 'Adj Close' value. Set the size of the figure to 13.5 x 9 inche

# %%
#Create your own question and answer it.

# %% [markdown]
# 2. FINANCIAL DATA

# %%
#Step 2. Create your time range (start and end variables). The start date should be 01/01/2015 and the end should today (whatever your today is)
pd.date_range(start='01/01/2015',end='06/11/2024')
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10',
#                ...
#                '2024-06-02', '2024-06-03', '2024-06-04', '2024-06-05',
#                '2024-06-06', '2024-06-07', '2024-06-08', '2024-06-09',
#                '2024-06-10', '2024-06-11'],
#               dtype='datetime64[ns]', length=3450, freq='D')

# %%
pip install yfinance
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/939.5 kB ? eta -:--:--
#      ---------------------------------------- 0.0/939.5 kB ? eta -:--:--
#      --------------------- ---------------- 524.3/939.5 kB 2.3 MB/s eta 0:00:01
#      ------------------------------- ------ 786.4/939.5 kB 2.2 MB/s eta 0:00:01
#      -------------------------------------- 939.5/939.5 kB 1.3 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.8 MB ? eta -:--:--
#    -------- ------------------------------- 0.8/3.8 MB 2.1 MB/s eta 0:00:02
# ...

# %%
import yfinance as yf

# %%
#Step 3. Select the Apple, Tesla, Twitter, IBM, LinkedIn stocks symbols and assign them to a variable called stocks
stocks =['AAPL','TSLA','TWTR','IBM','LNKD']

# %%
#step 4. Read the data from google, assign to df and print it
df = yf.download(stocks,period = '1y')
df
# Out:
# [*********************100%***********************]  5 of 5 completed
#
# 2 Failed downloads:
# ['TWTR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# ['LNKD']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (period=1y)')
# Price                       Adj Close                                    \
# Ticker                           AAPL         IBM LNKD        TSLA TWTR
# Date
# 2023-11-13 00:00:00+00:00  183.899078  144.059448  NaN  223.710007  NaN
# 2023-11-14 00:00:00+00:00  186.526215  146.306427  NaN  237.410004  NaN
# 2023-11-15 00:00:00+00:00  187.093414  148.417236  NaN  242.839996  NaN
# 2023-11-16 00:00:00+00:00  188.785141  148.884125  NaN  233.589996  NaN
# 2023-11-17 00:00:00+00:00  188.765228  148.718765  NaN  234.300003  NaN
# ...                               ...         ...  ...         ...  ...
# ...

# %%
#Step 5. What is the type of structure of df ?

# %%
# Print all the Items axis values
#To learn more about the Panel structure go to documentation

# %%
# Good, now we know the data avaiable. Create a dataFrame called vol, with the Volume values.
vol = yf.download(stocks,period = '1y')['Volume']
vol.head()
# Out:
# [*********************100%***********************]  5 of 5 completed
#
# 2 Failed downloads:
# ['LNKD']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (period=1y)')
# ['TWTR']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (period=1y) (Yahoo error = "No data found, symbol may be delisted")')
# Ticker                         AAPL      IBM  LNKD       TSLA  TWTR
# Date
# 2023-11-13 00:00:00+00:00  43627500  2647200   NaN  140447600   NaN
# 2023-11-14 00:00:00+00:00  60108400  4321900   NaN  149771600   NaN
# 2023-11-15 00:00:00+00:00  53790500  4632500   NaN  150354000   NaN
# 2023-11-16 00:00:00+00:00  54412900  3519200   NaN  136816800   NaN
# 2023-11-17 00:00:00+00:00  50922700  4426500   NaN  142532800   NaN

# %% [markdown]
# 3.INVESTOR FLOW OF FUNDS

# %%
#Assign it to a variable called funds
funds = pd.read_csv('https://raw.githubusercontent.com/datasets/investor-flow-of-funds-us/master/data/weekly.csv')
funds
# Out:
#           Date  Total Equity  Domestic Equity  World Equity  Hybrid  \
# 0   2012-12-05         -7426            -6060         -1367     -74
# 1   2012-12-12         -8783            -7520         -1263     123
# 2   2012-12-19         -5496            -5470           -26     -73
# 3   2012-12-26         -4451            -4076          -375     550
# 4   2013-01-02        -11156            -9622         -1533    -158
# 5   2013-01-09         14817             7995          6821    2888
# 6   2014-04-02          3155              938          2217     265
# 7   2014-04-09          5761             2080          3681    1482
# 8   2014-04-16          2286              634          1652    1186
# 9   2014-04-23          3530             1392          2138    1239
# 10  2014-04-30         -3890            -3996           106     759
# 11  2014-05-07           632            -2006          2639    -340
# 12  2014-05-14         -1079            -2321          1242    1188
# ...

# %%
#What is the frequency of the dataset?
Daily

# %%
#Set the column Date as the index
funds.set_index('Date',inplace=True)
funds.head(3)
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-12-05         -7426            -6060         -1367     -74        5317
# 2012-12-12         -8783            -7520         -1263     123        1818
# 2012-12-19         -5496            -5470           -26     -73         103
#
#             Taxable Bond  Municipal Bond  Total
# Date
# 2012-12-05          4210            1107  -2183
# 2012-12-12          1598             219  -6842
# 2012-12-19          3472           -3369  -5466

# %%
#What is the type of the index
funds.index.dtype
# Out:
# dtype('O')

# %%
#Set the index to a DatetimeIndex type
funds.index = pd.to_datetime(funds.index)
funds.index.dtype
# Out:
# dtype('<M8[ns]')

# %%
#Change the frequency to monthly, sum the values and assign it to monthly
monthly = funds.resample('ME').sum()
monthly
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-12-31        -26156           -23126         -3031     526        9848
# 2013-01-31          3661            -1627          5288    2730       12149
# 2013-02-28             0                0             0       0           0
# 2013-03-31             0                0             0       0           0
# 2013-04-30             0                0             0       0           0
# 2013-05-31             0                0             0       0           0
# 2013-06-30             0                0             0       0           0
# 2013-07-31             0                0             0       0           0
# 2013-08-31             0                0             0       0           0
# 2013-09-30             0                0             0       0           0
# 2013-10-31             0                0             0       0           0
# ...

# %%
#You will notice that it filled the dataFrame with months that don't have any data with NaN. Let's drop these rows.
monthly = monthly.loc[(monthly != 0).any(axis=1)]
monthly
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-12-31        -26156           -23126         -3031     526        9848
# 2013-01-31          3661            -1627          5288    2730       12149
# 2014-04-30         10842             1048          9794    4931        8493
# 2014-05-31         -2203            -8720          6518    3172       13767
# 2014-06-30          2319            -6546          8865    4588        9715
# 2014-07-31         -7051           -11128          4078    2666        7506
# 2014-08-31          1943            -5508          7452    1885        1897
# 2014-09-30         -2767            -6596          3829    1599        3984
# 2014-11-30         -2753            -7239          4485     729       14528
# 2015-01-31          3471            -1164          4635    1729        7368
# 2015-02-28          5508             3509          1999    1752        9099
# ...

# %%
#Good, now we have the monthly data. Now change the frequency to year.
yearly = monthly.resample('YE').sum()
yearly
# Out:
#             Total Equity  Domestic Equity  World Equity  Hybrid  Total Bond  \
# Date
# 2012-12-31        -26156           -23126         -3031     526        9848
# 2013-12-31          3661            -1627          5288    2730       12149
# 2014-12-31           330           -44689         45021   19570       59890
# 2015-12-31         15049           -10459         25508    7280       26028
#
#             Taxable Bond  Municipal Bond  Total
# Date
# 2012-12-31         12613           -2765 -15782
# 2013-12-31          9414            2735  18540
# 2014-12-31         44994           14896  79787
# 2015-12-31         17986            8041  48357

# %%
#Create your own question and answer it.

# %% [markdown]
# DELETING
# 1.IRIS

# %%
#Assign it to a variable called iris
iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
#Create columns for the dataset
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class
iris.columns = ['sepal_length(in cm)','sepal_width (in cm)','petal_length (in cm)','petal_width (in cm)','class']
iris.head(3)
# Out:
#    sepal_length(in cm)  sepal_width (in cm)  petal_length (in cm)  \
# 0                  4.9                  3.0                   1.4
# 1                  4.7                  3.2                   1.3
# 2                  4.6                  3.1                   1.5
#
#    petal_width (in cm)        class
# 0                  0.2  Iris-setosa
# 1                  0.2  Iris-setosa
# 2                  0.2  Iris-setosa

# %%
#Is there any missing value in the dataframe?
iris.isnull().sum()
# Out:
# sepal_length(in cm)     0
# sepal_width (in cm)     0
# petal_length (in cm)    0
# petal_width (in cm)     0
# class                   0
# dtype: int64

# %%
# Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
# Good, now lets substitute the NaN values to 1.0

# %%
#Now let's delete the column class

# %%
#Set the first 3 rows as NaN

# %%
#Delete the rows that have NaN

# %%
#Reset the index so it begins with 0 again

# %%
#Create your own question and answer it.

# %% [markdown]
# 2.WINE

# %%
# Assign it to a variable called wine
wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data')
wine
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
#Delete the first, fourth, seventh, nineth, eleventh, thirteenth and fourteenth columns
wine2 = wine.drop(['1','2.43','2.8','.28','5.64','3.92','1065'],axis=1)
wine2
# Out:
#      14.23  1.71  15.6  127  3.06  2.29  1.04
# 0    13.20  1.78  11.2  100  2.76  1.28  1.05
# 1    13.16  2.36  18.6  101  3.24  2.81  1.03
# 2    14.37  1.95  16.8  113  3.49  2.18  0.86
# 3    13.24  2.59  21.0  118  2.69  1.82  1.04
# 4    14.20  1.76  15.2  112  3.39  1.97  1.05
# ..     ...   ...   ...  ...   ...   ...   ...
# 172  13.71  5.65  20.5   95  0.61  1.06  0.64
# 173  13.40  3.91  23.0  102  0.75  1.41  0.70
# 174  13.27  4.28  20.0  120  0.69  1.35  0.59
# 175  13.17  2.59  20.0  120  0.68  1.46  0.60
# 176  14.13  4.10  24.5   96  0.76  1.35  0.61
#
# [177 rows x 7 columns]

# %%
#Assign the columns as below
# alcohol
# malic_acid
# alcalinity_of_ash
# magnesium
# flavanoids
# proanthocyanins
# hue
wine2.columns = ['alcohol','malic_acid','alcalinity_of_ash',' magnesium','flavanoids','proanthocyanins','hue']
wine2
# Out:
#      alcohol  malic_acid  alcalinity_of_ash   magnesium  flavanoids  \
# 0      13.20        1.78               11.2         100        2.76
# 1      13.16        2.36               18.6         101        3.24
# 2      14.37        1.95               16.8         113        3.49
# 3      13.24        2.59               21.0         118        2.69
# 4      14.20        1.76               15.2         112        3.39
# ..       ...         ...                ...         ...         ...
# 172    13.71        5.65               20.5          95        0.61
# 173    13.40        3.91               23.0         102        0.75
# 174    13.27        4.28               20.0         120        0.69
# 175    13.17        2.59               20.0         120        0.68
# 176    14.13        4.10               24.5          96        0.76
#
#      proanthocyanins   hue
# 0               1.28  1.05
# 1               2.81  1.03
# 2               2.18  0.86
# 3               1.82  1.04
# ...

# %%
#Set the values of the first 3 rows from alcohol as NaN

# %%
#Now set the value of the rows 3 and 4 of magnesium as NaN

# %%
#Fill the value of NaN with the number 10 in alcohol and 100 in magnesium

# %%
#Count the number of missing values

# %%
# Create an array of 10 random numbers up until 10

# %%
#Use random numbers you generated as an index and assign NaN value to each of cell.

# %%
#How many missing values do we have?

# %%
#Delete the rows that contain missing values

# %%
#Print only the non-null values in alcohol

# %%
#Reset the index, so it starts with 0 again

# %%
#Create your own question and answer it.
